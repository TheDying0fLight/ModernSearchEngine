# %%
# %load_ext autoreload
# %autoreload 2

import urllib.robotparser as urobot

url = "https://www.google.com"
ggl = urobot.RobotFileParser()
ggl.set_url(url + "/robots.txt")
ggl.read()
print("Google:")
print(ggl.can_fetch("*", "/search/about"))
print(ggl.can_fetch("*", "/search"))

url = "https://en.wikipedia.org"
wiki = urobot.RobotFileParser()
wiki.set_url(url + "/robots.txt")
wiki.read()
print("\nWiki:")
print(wiki.can_fetch("*", "/api/"))
print(wiki.can_fetch("*", "/api/More"))
print(wiki.can_fetch("*", "/api/rest_v1/?doc"))
print(wiki.can_fetch("*", "/wiki/George_Washington"))
# Out:
# Google:
# False
# False
#
# Wiki:
# False
# False
# True
# True

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse

test = "https://en.wikipedia.org/wiki/Baden-W%C3%BCrttemberg"
resp = requests.get(test, timeout=10)
soup = BeautifulSoup(resp.content, 'html.parser')
title = soup.title.string if soup.title and soup.title.string else "No title found"
for link in soup.findAll('a', href=True):
        print(link.string, urlparse(link['href']).path)
# Out:
# Jump to content #bodyContent
# Main page /wiki/Main_Page
# Contents /wiki/Wikipedia:Contents
# Current events /wiki/Portal:Current_events
# Random article /wiki/Special:Random
# About Wikipedia /wiki/Wikipedia:About
# Contact us /wiki/Wikipedia:Contact_us
# Help /wiki/Help:Contents
# Learn to edit /wiki/Help:Introduction
# Community portal /wiki/Wikipedia:Community_portal
# Recent changes /wiki/Special:RecentChanges
# Upload file /wiki/Wikipedia:File_upload_wizard
# Special pages /wiki/Special:SpecialPages
# None /wiki/Main_Page
# None /wiki/Special:Search
# Donate https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# Create account /w/index.php
# Log in /w/index.php
# Donate https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# None /w/index.php
# None /w/index.php
# learn more /wiki/Help:Introduction
# Contributions /wiki/Special:MyContributions
# ...
